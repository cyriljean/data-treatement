# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import chargement

# %%
dos=chargement.dossier(2014,12)
# Out:
# Les fichiers XXm_ ne sont pas ranges dans le dossier du mois correspondant !

# %%
traitement=chargement.traitement(2014,12,'08')

# %%
tracetemporelle=traitement.temporel()

# %%
tracefrequentielle=traitement.frequentiel(Puissance=True)

# %%
traiter=traitement.fichieratraiter()

# %%
fichier_path=[item[0]+'/'+item[1][0] for item in traiter]

# %%
fichier_path[0]
# Out:
# '/home/cyril/Documents/data_pompe_sonde/2014/12/08/dat/A/081203A.dat'

# %%
vecteur=tracetemporelle[fichier_path[0]]
traitement.plotter(temps=vecteur[0],signal=vecteur[1],fit=vecteur[2],nomfigure=vecteur[3],xlim=vecteur[4],abscisse=vecteur[5],fitter=True)

# %%
vecteurf=tracefrequentielle[fichier_path[0]]
traitement.plotter(temps=vecteurf[0],signal=vecteurf[1],fit=[],nomfigure=vecteurf[2],xlim=[0,20],abscisse=vecteurf[4],ordonnee=vecteurf[5])

# %%
for key in fichier_path:
    vecteur=tracetemporelle[key]
    traitement.plotter(temps=vecteur[0],signal=vecteur[1],fit=vecteur[2],nomfigure=vecteur[3],xlim=vecteur[4],abscisse=vecteur[5],fitter=True)
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.py:412: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)

# %%
for key in fichier_path:
    vecteurf=tracefrequentielle[key]
    traitement.plotter(temps=vecteurf[0],signal=vecteurf[1],fit=[],nomfigure=vecteurf[2],xlim=[0,20],abscisse=vecteurf[4],ordonnee=vecteurf[5])
